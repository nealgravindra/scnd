# %%
# %matplotlib inline
# %load_ext memory_profiler

import pandas as pd
import os
import glob
import pickle
import phate
import scprep
import graphtools as gt
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import time
import datetime
import scanpy as sc
import math
from scipy import sparse
import sys
sys.path.append('/home/ngr4/project/scripts/')
import utils
import magic

import random
from scipy.stats import kendalltau

# settings
plt.rc('font', size = 9)
plt.rc('font', family='sans serif')
plt.rcParams['pdf.fonttype']=42
plt.rcParams['ps.fonttype']=42
plt.rcParams['text.usetex']=False
plt.rcParams['legend.frameon']=False
plt.rcParams['axes.grid']=False
plt.rcParams['legend.markerscale']=0.5
sc.set_figure_params(dpi=300,dpi_save=600,
                     frameon=False,
                     fontsize=9)
plt.rcParams['savefig.dpi']=600
sc.settings.verbosity=2
sc._settings.ScanpyConfig.n_jobs=-1
sns.set_style("ticks")

# %%
# %%memit
#
# pdfp = '/home/ngr4/project/scnd/data/processed'
# pfp = '/home/ngr4/project/scnd/results/'
# sc.settings.figdir = pfp
#
# wt = utils.load_adata(os.path.join(pdfp,'mouse_wt_imputed.h5ad'))
# mut = utils.load_adata(os.path.join(pdfp,'mouse_sca1_imputed.h5ad'))
# Out:
# loaded @210201.16:31:36
# took 39.49-s to load data
# loaded @210201.16:32:16
# took 40.00-s to load data
# peak memory: 74515.18 MiB, increment: 74311.13 MiB

# %%
def kendall(AnnData, n=100, save=None, verbose=False):
    if verbose:
        tic = time.time()
    results = pd.DataFrame(columns=['tau', 'P'], index=AnnData.var_names.to_list())
    cell_sample = random.sample(AnnData.obs.index.to_list(), n)   
    for i, g in enumerate(AnnData.var_names):
        x = np.asarray(AnnData[AnnData.obs.index.isin(cell_sample), g].X.todense()).flatten()
        ximp = np.asarray(AnnData[AnnData.obs.index.isin(cell_sample), g].layers['imputed']).flatten()
        tau, p = kendalltau(x, ximp)
        results.loc[g, 'tau'] = tau
        results.loc[g, 'P'] = p
        
        if i % 1000 == 0 and i != 0 and verbose:
            print('Through {:.2f}-% in {:.1f}-s. Iterative saved'.format(100*(i/results.shape[0]), time.time() - tic))
            if save is not None:
                results.to_csv(save)      
    if save is not None:
        results.to_csv(save)
    return results

# %%
tau_wt = kendall(wt, save='/home/ngr4/project/scnd/results/magic_kendalltau_wt.csv', verbose=True)
tau_mut = kendall(mut, save='/home/ngr4/project/scnd/results/magic_kendalltau_sca1.csv', verbose=True)
# Out:
# Through 3.79-% in 31.1-s. Iterative saved
# Through 7.58-% in 60.9-s. Iterative saved
# Through 11.37-% in 90.8-s. Iterative saved
# Through 15.17-% in 120.6-s. Iterative saved
# Through 18.96-% in 150.6-s. Iterative saved
# Through 22.75-% in 180.7-s. Iterative saved
# Through 26.54-% in 211.5-s. Iterative saved
# Through 30.33-% in 242.7-s. Iterative saved
# Through 34.12-% in 274.2-s. Iterative saved
# Through 37.92-% in 305.5-s. Iterative saved
# Through 41.71-% in 336.8-s. Iterative saved
# Through 45.50-% in 367.8-s. Iterative saved
# Through 49.29-% in 398.0-s. Iterative saved
# Through 53.08-% in 428.3-s. Iterative saved
# Through 56.87-% in 458.7-s. Iterative saved
# Through 60.67-% in 489.2-s. Iterative saved
# Through 64.46-% in 519.7-s. Iterative saved
# Through 68.25-% in 550.2-s. Iterative saved
# Through 72.04-% in 581.7-s. Iterative saved
# Through 75.83-% in 613.6-s. Iterative saved
# Through 79.62-% in 645.6-s. Iterative saved
# Through 83.42-% in 677.5-s. Iterative saved
# Through 87.21-% in 709.7-s. Iterative saved
# Through 91.00-% in 740.5-s. Iterative saved
# Through 94.79-% in 771.4-s. Iterative saved
# Through 98.58-% in 802.6-s. Iterative saved

# %%
tau_wt
# Out:
#         Gene       tau             P Genotype
# 0          0  0.406420  9.057028e-09       WT
# 1          1  0.248435  1.861965e-03       WT
# 2          2       NaN           NaN       WT
# 3          3  0.141421  8.637896e-02       WT
# 4          4       NaN           NaN       WT
# ...      ...       ...           ...      ...
# 26369  26369       NaN           NaN       WT
# 26370  26370       NaN           NaN       WT
# 26371  26371  0.331298  2.336614e-06       WT
# 26372  26372  0.179931  2.794870e-02       WT
# 26373  26373       NaN           NaN       WT
#
# [26374 rows x 4 columns]

# %%
# visualize
if True:
    # load tau_wt
    tau_wt = pd.read_csv('/home/ngr4/project/scnd/results/magic_kendalltau_wt.csv', index_col=0)
    tau_mut = pd.read_csv('/home/ngr4/project/scnd/results/magic_kendalltau_sca1.csv', index_col=0)
results_wt = tau_wt
results_mut = tau_mut
results_wt['Genotype'] = 'WT'
results_wt['Gene'] = results_wt.index.to_list()
results_mut['Genotype'] = 'SCA1'
results_mut['Gene'] = results_mut.index.to_list()

results = results_wt.append(results_mut, ignore_index=True)
results['-log10P'] = results['P']
results['-log10P'].loc[results['P']==0] = results['P'].loc[results['P']!=0].min()
results['-log10P'] = -1 * np.log10(results['-log10P'])

fig, ax = plt.subplots(1, 2, figsize=(4, 1.67))
sns.ecdfplot(x='tau', data=results, hue='Genotype', ax=ax[0], legend=False)
sns.ecdfplot(x='-log10P', data=results, hue='Genotype', ax=ax[1])
ax[0].set_xlabel("Kendall's tau")
ax[0].plot([ax[0].get_xlim()[0], ax[0].get_xlim()[1]], [0.5, 0.5], 'k--')
ax[1].plot([ax[1].get_xlim()[0], ax[1].get_xlim()[1]], [0.5, 0.5], 'k--')
ax[1].plot([2,2], [ax[1].get_ylim()[0], ax[1].get_ylim()[1]], 'k--')
ax[1].set_xlabel('-log10 P')
ax[1].set_ylabel('')
fig.tight_layout()
# Out:
# /gpfs/ycga/project/dijk/ngr4/conda_envs/rnavel/lib/python3.7/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
def check_corrs(AnnData, gene_list, obs_vars, 
                n=100, save=None, verbose=False):
    if verbose:
        tic = time.time()
    results = pd.DataFrame(columns=[i+'_tau' for i in obs_vars]+[i+'_P' for i in obs_vars], 
                           index=gene_list)
    cell_sample = random.sample(AnnData.obs.index.to_list(), n)   
    for i, g in enumerate(gene_list):
        x = np.asarray(AnnData[AnnData.obs.index.isin(cell_sample), g].X.todense()).flatten()
        for j in obs_vars:
            y = AnnData[AnnData.obs.index.isin(cell_sample), :].obs[j].to_numpy()
            tau, p = kendalltau(x, y)
            results.loc[g, j+'_tau'] = tau
            results.loc[g, j+'_P'] = p 
        if i % 25 == 0 and i != 0 and verbose:
            print('  through {:.2f}-% in {:.1f}-s'.format(100*(i/results.shape[0]), time.time() - tic))
            if save is not None:
                results.to_csv(save)
                print('    itereatively saved.')
    if save is not None:
        results.to_csv(save)
    return results

# %%
if True:
    # load tau_wt
    tau_wt = pd.read_csv('/home/ngr4/project/scnd/results/magic_kendalltau_wt.csv', index_col=0)
qc_vars = ['n_genes_by_counts', 'total_counts', 'pmito', 'ees_sca1']
bottom_n = 100
goi = tau_wt.sort_values(by='tau').index.to_list()[:bottom_n]
print('Worst n={}\t<tau>:{:.2f}'.format(bottom_n, tau_wt.loc[goi, 'tau'].mean()))
print('Worst n={}\t<P>:{:.2e}'.format(bottom_n, tau_wt.loc[goi, 'P'].mean()))
qc_wt = check_corrs(wt, goi, qc_vars, n=500,
                    save='/home/ngr4/project/scnd/results/magic_kendalltau_qc_wt.csv', verbose=True)
# Out:
# Worst n=100	<tau>:0.07
# Worst n=100	<P>:3.72e-01
#   through 25.00-% in 2.3-s
#     itereatively saved.
#   through 50.00-% in 4.5-s
#     itereatively saved.
#   through 75.00-% in 6.7-s
#     itereatively saved.

# %%
# visualize
qc_wt = qc_wt.reset_index()
qc_wt = qc_wt.rename(columns={'index':'Gene'})
dt = pd.melt(qc_wt, id_vars='Gene', value_vars=[i for i in qc_wt.columns if i!='Gene'], var_name='Quality metric')
dt['value_type'] = [i.split('_')[-1] for i in dt['Quality metric']]
# merge tau from other matrix
tau_wt = tau_wt.reset_index()
tau_wt = tau_wt.rename(columns={'index':'Gene'})
dt = pd.merge(dt, tau_wt.loc[:, ['Gene', 'tau']], left_on='Gene', right_on='Gene')
fig, ax = plt.subplots(1, 1, figsize=(3,2))
sns.scatterplot(x='tau', y='value',
                hue='Quality metric', 
                data=dt.loc[dt['value_type']=='tau', :], 
                linewidth=0,
                ax=ax)
ax.legend(bbox_to_anchor=(1.1, 1))
ax.set_ylabel('Quality metric and\ngene expression correlation')
ax.set_xlabel('Imputed and normed and\nsqrt transformed expression correlation')
ax.set_title('100 genes lowest imputation\nv. no-imputation correlation')
# Out:
# Text(0.5, 1.0, '100 genes lowest imputation\nv. no-imputation correlation')

# %%
# visualize correlations 
# results_wt['Genotype'] = 'WT'
# results_wt['Gene'] = results_wt.index.to_list()
# results_mut['Genotype'] = 'SCA1'
# results_mut['Gene'] = results_mut.index.to_list()

# results = results_wt.append(results_mut, ignore_index=True)
# results['-log10P'] = results['P']
# results['-log10P'].loc[results['P']==0] = results['P'].loc[results['P']!=0].min()
# results['-log10P'] = -1 * np.log10(results['-log10P'])

fig, ax = plt.subplots(1, 2, figsize=(4, 1.67))
sns.ecdfplot(x='rho', data=results, hue='Genotype', ax=ax[0], legend=False)
sns.ecdfplot(x='-log10P', data=results, hue='Genotype', ax=ax[1])
ax[0].set_xlabel('Spearman rho')
ax[1].plot([2,2], [ax[1].get_ylim()[0], ax[1].get_ylim()[1]], 'k--')
ax[1].set_xlabel('-log10 P')
ax[1].set_ylabel('')
fig.tight_layout()

# %%
wt.obs.ctype.unique()
# Out:
# [Bergmann glia, Granule cell, Astrocyte, Oligodendrocyte, Unipolar brush cell, ..., Endothelial cell, Pericyte, Purkinje cell, GABAergic interneuron 3, Oligodendrocyte progenitor cell]
# Length: 13
# Categories (13, object): [Bergmann glia, Granule cell, Astrocyte, Oligodendrocyte, ..., Pericyte, Purkinje cell, GABAergic interneuron 3, Oligodendrocyte progenitor cell]

# %% [markdown]
# # dev

# %%
x = pd.read_csv(os.path.join(pfp, 'imp_corr_wt_nonzero.csv'), index_col=0)

# %%
xprime = x.loc[x['P']> 0.05]
xprime['abs_rho'] = xprime['rho'].abs()
xprime.sort_values(by='abs_rho').head(n=20)
# Out:
# <ipython-input-17-ef7f979fd41a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xprime['abs_rho'] = xprime['rho'].abs()
#                rho       P   abs_rho
# Olfr921   0.000000  1.0000  0.000000
# Ferd3l    0.000000  1.0000  0.000000
# Gm29090   0.000000  1.0000  0.000000
# Gm45431   0.000000  1.0000  0.000000
# Upk2      0.000000  1.0000  0.000000
# Gm14199   0.000000  1.0000  0.000000
# Olfr361   0.000000  1.0000  0.000000
# Serpina6  0.000000  1.0000  0.000000
# Gm33570   0.000000  1.0000  0.000000
# Gm37419   0.000000  1.0000  0.000000
# Gm7945    0.000000  1.0000  0.000000
# Gm12970   0.000000  1.0000  0.000000
# Ang5      0.000000  1.0000  0.000000
# Saa4      0.000000  1.0000  0.000000
# Pla2g2f   0.000000  1.0000  0.000000
# Gm15389   0.000000  1.0000  0.000000
# Gm45095   0.000000  1.0000  0.000000
# Fmo6      0.000000  1.0000  0.000000
# Gm48801   0.000000  1.0000  0.000000
# Ghdc      0.000029  0.9989  0.000029

# %% [markdown]
# # Data imputation concerns
#
# Concenrs over artifacts introduced by MAGIC
#
# ## Benchmarking MAGIC
#
# Need to validate, computationally, with whatever normally would do (see van Dijk original manuscript)
#
# ### imputed and raw expression correlation
#
# Question about zeros, so maybe try without? Then, see what it is about poorly correlating genes that make them poorly correlation (see how they fit into differnetial expression groups of cell types, or whether their expression is correlated with noise or some other data quality metric)
#
# Alternatively, could just do Kendall's tau-b, which is adapted to handl ties ([see this post](https://stackoverflow.com/questions/10711395/spearman-correlation-and-ties))
#
# #### excluding 0s

# %%
# %%memit
#
# tic = time.time()
# from scipy.stats import spearmanr
# rho, p = np.zeros((wt.shape[1],)), np.zeros((wt.shape[1],))
# X = np.asarray(wt.X.todense()) # memory intensive
# for i in range(wt.shape[1]):
#     # check where that gene is >0 counts
#     nonzero_idx = np.asarray((wt.raw[:, i].X>0).todense()).flatten()
#     if np.sum(nonzero_idx) == 0:
#         #continue; else:
#         print('No counts for {}'.format(wt.var_names[i]))
#     rho[i], p[i] = spearmanr(X[nonzero_idx, i], wt.layers['imputed'][nonzero_idx, i], nan_policy='raise')
#     if i % 200 == 0 and i!=0:
#         print('{:.2f}-s elapsed\tthrough {:.2f}-% of iterations'.format(time.time() - tic, 100*(i/wt.shape[1])))
# toc = time.time()
#
# print('Correlations in {:.2f}-min'.format((toc-tic)/60))
# Out:
# No counts for Gm5524
# 88.62-s elapsed	through 0.76-% of iterations
# 166.15-s elapsed	through 1.52-% of iterations
# 243.32-s elapsed	through 2.27-% of iterations
# 319.93-s elapsed	through 3.03-% of iterations
# 397.63-s elapsed	through 3.79-% of iterations
# No counts for Gm33994
# 474.78-s elapsed	through 4.55-% of iterations
# 551.18-s elapsed	through 5.31-% of iterations
# No counts for Gm33973
# 628.50-s elapsed	through 6.07-% of iterations
# No counts for Il1f5
# 705.46-s elapsed	through 6.82-% of iterations
# 782.35-s elapsed	through 7.58-% of iterations
# 859.94-s elapsed	through 8.34-% of iterations
# No counts for Prg3
# 936.83-s elapsed	through 9.10-% of iterations
# No counts for Olfr1065
# No counts for Olfr1082
# No counts for Olfr1135
# No counts for Olfr142
# 1013.21-s elapsed	through 9.86-% of iterations
# 1089.84-s elapsed	through 10.62-% of iterations
# 1167.12-s elapsed	through 11.37-% of iterations
# 1244.06-s elapsed	through 12.13-% of iterations
# No counts for Bpifb3
# 1320.51-s elapsed	through 12.89-% of iterations
# No counts for Gm28163
# 1397.33-s elapsed	through 13.65-% of iterations
# No counts for Ssxb2
# 1476.01-s elapsed	through 14.41-% of iterations
# 1554.82-s elapsed	through 15.17-% of iterations
# 1632.44-s elapsed	through 15.92-% of iterations
# 1709.15-s elapsed	through 16.68-% of iterations
# 1785.94-s elapsed	through 17.44-% of iterations
# No counts for Gm16508
# 1863.00-s elapsed	through 18.20-% of iterations
# No counts for C130079G13Rik
# 1939.77-s elapsed	through 18.96-% of iterations
# No counts for Gm9117
# 2016.35-s elapsed	through 19.72-% of iterations
# 2092.81-s elapsed	through 20.47-% of iterations
# No counts for Gstm3
# No counts for Amy2a5
# 2169.76-s elapsed	through 21.23-% of iterations
# 2246.22-s elapsed	through 21.99-% of iterations
# No counts for Gm12354
# 2323.20-s elapsed	through 22.75-% of iterations
# 2400.15-s elapsed	through 23.51-% of iterations
# No counts for Mup20
# No counts for Mup21
# No counts for Ifnab
# 2477.09-s elapsed	through 24.27-% of iterations
# No counts for Dmrta2os
# 2553.46-s elapsed	through 25.02-% of iterations
# 2630.48-s elapsed	through 25.78-% of iterations
# 2707.28-s elapsed	through 26.54-% of iterations
# 2783.29-s elapsed	through 27.30-% of iterations
# No counts for Gm32877
# No counts for Gm21190
# 2859.90-s elapsed	through 28.06-% of iterations
# 2937.23-s elapsed	through 28.82-% of iterations
# 3013.84-s elapsed	through 29.57-% of iterations
# 3090.17-s elapsed	through 30.33-% of iterations
# No counts for Gm31048
# 3167.07-s elapsed	through 31.09-% of iterations
# 3243.87-s elapsed	through 31.85-% of iterations
# 3320.69-s elapsed	through 32.61-% of iterations
# 3398.04-s elapsed	through 33.37-% of iterations
# 3474.64-s elapsed	through 34.12-% of iterations
# 3551.17-s elapsed	through 34.88-% of iterations
# 3627.33-s elapsed	through 35.64-% of iterations
# No counts for Vmn1r23
# No counts for Gm44427
# 3704.00-s elapsed	through 36.40-% of iterations
# 3780.52-s elapsed	through 37.16-% of iterations
# 3857.03-s elapsed	through 37.92-% of iterations
# No counts for Fgf6
# No counts for Gm44009
# No counts for Klrb1c
# No counts for Cd69
# 3933.12-s elapsed	through 38.67-% of iterations
# 4009.11-s elapsed	through 39.43-% of iterations
# No counts for Gm44733
# No counts for Vmn2r33
# 4084.79-s elapsed	through 40.19-% of iterations
# 4160.53-s elapsed	through 40.95-% of iterations
# 4237.10-s elapsed	through 41.71-% of iterations
# 4312.69-s elapsed	through 42.47-% of iterations
# 4388.78-s elapsed	through 43.22-% of iterations
# No counts for Olfr290
# 4465.98-s elapsed	through 43.98-% of iterations
# No counts for Olfr305
# No counts for Olfr33
# No counts for Olfr596
# 4542.21-s elapsed	through 44.74-% of iterations
# 4618.07-s elapsed	through 45.50-% of iterations
# 4694.66-s elapsed	through 46.26-% of iterations
# 4770.84-s elapsed	through 47.02-% of iterations
# 4847.20-s elapsed	through 47.77-% of iterations
# 4923.07-s elapsed	through 48.53-% of iterations
# 4999.69-s elapsed	through 49.29-% of iterations
# 5075.72-s elapsed	through 50.05-% of iterations
# 5151.79-s elapsed	through 50.81-% of iterations
# 5228.28-s elapsed	through 51.57-% of iterations
# No counts for 1700025K04Rik
# 5304.45-s elapsed	through 52.32-% of iterations
# No counts for Cd209d
# 5379.76-s elapsed	through 53.08-% of iterations
# No counts for Defb3
# 5455.30-s elapsed	through 53.84-% of iterations
# 5531.60-s elapsed	through 54.60-% of iterations
# 5607.57-s elapsed	through 55.36-% of iterations
# 5683.84-s elapsed	through 56.12-% of iterations
# No counts for Ces3b
# 5760.01-s elapsed	through 56.87-% of iterations
# 5836.55-s elapsed	through 57.63-% of iterations
# No counts for Gm32123
# 5912.22-s elapsed	through 58.39-% of iterations
# 5987.98-s elapsed	through 59.15-% of iterations
# No counts for Trav3-1
# 6063.83-s elapsed	through 59.91-% of iterations
# 6139.96-s elapsed	through 60.67-% of iterations
# No counts for Gm49048
# 6215.84-s elapsed	through 61.42-% of iterations
# No counts for 4921530L21Rik
# No counts for 4930435M08Rik
# 6293.96-s elapsed	through 62.18-% of iterations
# 6371.18-s elapsed	through 62.94-% of iterations
# No counts for Olfr877
# No counts for Olfr150
# 6448.47-s elapsed	through 63.70-% of iterations
# 6526.61-s elapsed	through 64.46-% of iterations
# No counts for Gm47235
# 6606.43-s elapsed	through 65.22-% of iterations
# No counts for Gm3776
# 6684.49-s elapsed	through 65.97-% of iterations
# 6760.87-s elapsed	through 66.73-% of iterations
# 6836.83-s elapsed	through 67.49-% of iterations
# No counts for Gm19385
# No counts for Gm47070
# 6912.83-s elapsed	through 68.25-% of iterations
# No counts for Gm11983
# 6988.97-s elapsed	through 69.01-% of iterations
# No counts for Olfr1389
# 7065.30-s elapsed	through 69.77-% of iterations
# 7141.16-s elapsed	through 70.52-% of iterations
# No counts for Olfr384
# 7217.11-s elapsed	through 71.28-% of iterations
# 7293.49-s elapsed	through 72.04-% of iterations
# 7369.83-s elapsed	through 72.80-% of iterations
# 7445.85-s elapsed	through 73.56-% of iterations
# 7522.07-s elapsed	through 74.32-% of iterations
# 7598.49-s elapsed	through 75.07-% of iterations
# No counts for Olfr11
# No counts for Vmn1r189
# No counts for Vmn1r193
# 7673.83-s elapsed	through 75.83-% of iterations
# No counts for Gm36099
# 7749.23-s elapsed	through 76.59-% of iterations
# No counts for Barx1
# 7825.20-s elapsed	through 77.35-% of iterations
# No counts for Gm26806
# 7900.82-s elapsed	through 78.11-% of iterations
# No counts for 4933416O17Rik
# 7976.70-s elapsed	through 78.87-% of iterations
# 8052.29-s elapsed	through 79.62-% of iterations
# No counts for Gm20767
# 8128.18-s elapsed	through 80.38-% of iterations
# 8204.25-s elapsed	through 81.14-% of iterations
# 8280.23-s elapsed	through 81.90-% of iterations
# No counts for Gm47804
# 8356.89-s elapsed	through 82.66-% of iterations
# 8432.60-s elapsed	through 83.42-% of iterations
# 8508.56-s elapsed	through 84.17-% of iterations
# No counts for AC087116.1
# 8584.19-s elapsed	through 84.93-% of iterations
# No counts for Gpihbp1
# 8660.15-s elapsed	through 85.69-% of iterations
# 8736.33-s elapsed	through 86.45-% of iterations
# No counts for Gm47841
# 8811.86-s elapsed	through 87.21-% of iterations
# 8888.15-s elapsed	through 87.97-% of iterations
# No counts for CT009704.1
# 8964.09-s elapsed	through 88.72-% of iterations
# 9040.13-s elapsed	through 89.48-% of iterations
# No counts for Olfr190
# 9115.79-s elapsed	through 90.24-% of iterations
# 9192.46-s elapsed	through 91.00-% of iterations
# No counts for Prss21
# 9268.17-s elapsed	through 91.76-% of iterations
# 9344.04-s elapsed	through 92.52-% of iterations
# 9419.53-s elapsed	through 93.27-% of iterations
# 9495.35-s elapsed	through 94.03-% of iterations
# 9571.78-s elapsed	through 94.79-% of iterations
# No counts for Gm20820
# No counts for Gm16344
# 9647.71-s elapsed	through 95.55-% of iterations
# No counts for Gm5689
# 9724.42-s elapsed	through 96.31-% of iterations
# 9800.80-s elapsed	through 97.07-% of iterations
# 9877.26-s elapsed	through 97.82-% of iterations
# No counts for Olfr76
# No counts for Olfr1484
# No counts for Dmrt2
# 9953.32-s elapsed	through 98.58-% of iterations
# No counts for Gm29593
# 10029.27-s elapsed	through 99.34-% of iterations
# No counts for 1700016H03Rik
# Correlations in 168.25-min
# peak memory: 71799.09 MiB, increment: 16543.98 MiB

# %%
results_wt = pd.DataFrame({'rho':rho, 'P':p}, index=wt.var_names.to_list())
results_wt.to_csv(os.path.join(pfp, 'imp_corr_wt_nonzero.csv'))

# %% [markdown]
# #### including 0s

# %%
# using kendall's tau-b
# %%memit 

tic = time.time()
from scipy.stats import kendalltau
rho, p = np.zeros((wt.shape[1],)), np.zeros((wt.shape[1],)) 
X = np.asarray(wt.X.todense()) # memory intensive
for i in range(wt.shape[1]):
    rho[i], p[i] = kendalltau(X[:, i], wt.layers['imputed'][:, i])
    if i % 750 == 0 and i!=0:
        print('{:.2f}-s elapsed\tthrough {:.2f}-% of iterations'.format(time.time() - tic, 100*(i/wt.shape[1])kendalltau= time.time()
    
print('Correlations in {:.2f}-min'.format((toc-tic)/60))

# %%
results_wt = pd.DataFrame({'rho':rho, 'P':p}, index=wt.var_names.to_list())
results_wt.to_csv(os.path.join(pfp, 'imp_kendalltau_wt.csv'))

# %%
# %%memit
#
# tic = time.time()
# from scipy.stats import spearmanr
# rho, p = np.zeros((wt.shape[1],)), np.zeros((wt.shape[1],))
# X = np.asarray(wt.X.todense()) # memory intensive
# for i in range(wt.shape[1]):
#     rho[i], p[i] = spearmanr(X[:, i], wt.layers['imputed'][:, i], nan_policy='raise')
# toc = time.time()
#
# print('Correlations in {:.2f}-min'.format((toc-tic)/60))
# Out:
# /gpfs/ycga/project/dijk/ngr4/conda_envs/py385dev/lib/python3.8/site-packages/scipy/stats/stats.py:4196: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# Correlations in 21.40-min
# peak memory: 91099.12 MiB, increment: 16585.34 MiB

# %%
results_wt = pd.DataFrame({'rho':rho, 'P':p}, index=wt.var_names.to_list())
results_wt.to_csv(os.path.join(pfp, 'imp_corr_wt.csv'))

# %%
# %%memit
#
# tic = time.time()
# from scipy.stats import spearmanr
# rho, p = np.zeros((mut.shape[1],)), np.zeros((mut.shape[1],))
# X = np.asarray(mut.X.todense()) # memory intensive
# for i in range(mut.shape[1]):
#     rho[i], p[i] = spearmanr(X[:, i], mut.layers['imputed'][:, i], nan_policy='raise')
# toc = time.time()
#
# print('Correlations in {:.2f}-min'.format((toc-tic)/60))
#
# results_mut = pd.DataFrame({'rho':rho, 'P':p}, index=mut.var_names.to_list())
# results_mut.to_csv(os.path.join(pfp, 'imp_corr_mut.csv'))
# Out:
# Correlations in 20.03-min
# peak memory: 106407.30 MiB, increment: 15308.00 MiB

# %%
results_wt = pd.DataFrame({'rho':rho, 'P':p}, index=wt.var_names.to_list())

sns.ecdfplot(x='rho', data=results_wt)
# Out:
# <AxesSubplot:xlabel='rho', ylabel='Proportion'>

# %%
results_wt['Genotype'] = 'WT'
results_wt['Gene'] = results_wt.index.to_list()
results_mut['Genotype'] = 'SCA1'
results_mut['Gene'] = results_mut.index.to_list()

results = results_wt.append(results_mut, ignore_index=True)
results['-log10P'] = results['P']
results['-log10P'].loc[results['P']==0] = results['P'].loc[results['P']!=0].min()
results['-log10P'] = -1 * np.log10(results['-log10P'])
# Out:
# /gpfs/ycga/project/dijk/ngr4/conda_envs/py385dev/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
fig, ax = plt.subplots(1, 2, figsize=(4, 1.67))
sns.ecdfplot(x='rho', data=results, hue='Genotype', ax=ax[0], legend=False)
sns.ecdfplot(x='-log10P', data=results, hue='Genotype', ax=ax[1])
ax[0].set_xlabel('Spearman rho')
ax[1].plot([2,2], [ax[1].get_ylim()[0], ax[1].get_ylim()[1]], 'k--')
ax[1].set_xlabel('-log10 P')
ax[1].set_ylabel('')
fig.tight_layout()

# %%
fig, ax = plt.subplots(1,1, figsize=(2,1.67))
sns.boxplot(x='Genotype', y='-log10P', data=results, hue='Genotype', ax=ax)
# Out:
# <AxesSubplot:xlabel='Genotype', ylabel='-log10P'>

# %%
np.asarray(wt[:, 'Xkr4'].X.todense()).flatten().shape
# Out:
# (164722,)

# %%
results_wt.head()
# Out:
#               rho              P Genotype     Gene
# Xkr4     0.535164   0.000000e+00       WT     Xkr4
# Gm1992   0.383737   0.000000e+00       WT   Gm1992
# Gm37381  0.058955  9.669012e-127       WT  Gm37381
# Rp1      0.169754   0.000000e+00       WT      Rp1
# Sox17    0.127944   0.000000e+00       WT    Sox17

# %%
g = 'Xkr4'
fig, ax = plt.subplots(1,1, figsize=(2,1.67))
sns.scatterplot(x=np.asarray(wt[:, g].X.todense()).flatten(), 
                y=np.asarray(wt[:, g].layers['imputed']).flatten(),
                lw=0, s=1,
               ax=ax)
ax.set_xlabel('Normed and sqrt transformed counts')
ax.set_ylabel('Imputed (MAGIC)')
ax.set_title(g)
# Out:
# /gpfs/ycga/project/dijk/ngr4/conda_envs/py385dev/lib/python3.8/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# Text(0.5, 1.0, 'Xkr4')

# %%
X = np.asarray(wt[0:2000, :].X.todense())
Xprime = np.asarray(wt[0:2000, :].layers['imputed'])

# %%
Xprime
# Out:
# array([[1.83202338e-01, 2.57069946e-03, 1.20239341e-03, ...,
#         8.39039091e-01, 6.58203191e-02, 2.01742926e-02],
#        [1.12667037e+00, 1.01855253e-01, 0.00000000e+00, ...,
#         4.03259298e-01, 1.03413278e-02, 1.24549727e-03],
#        [1.02500330e-01, 3.86869081e-03, 1.58965139e-04, ...,
#         8.29832329e-01, 5.89320931e-02, 0.00000000e+00],
#        ...,
#        [9.21769217e-01, 8.89148586e-02, 4.43122088e-04, ...,
#         9.19038363e-01, 5.90923784e-02, 2.37929284e-03],
#        [1.01148715e+00, 7.95929984e-02, 1.13143588e-03, ...,
#         9.28798799e-01, 2.62044592e-02, 3.12081374e-03],
#        [1.92492302e+00, 3.30191103e-01, 5.18933629e-04, ...,
#         1.18109359e+00, 3.43556851e-02, 3.25348862e-03]])

# %%
sns.clustermap(X, cmap='YlOrBr')
# Out:
# /gpfs/ycga/project/dijk/ngr4/conda_envs/py385dev/lib/python3.8/site-packages/seaborn/matrix.py:659: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-482bb86dbff2> in <module>
# ----> 1 sns.clustermap(X, cmap='YlOrBr')
#
# /gpfs/ycga/project/dijk/ngr4/conda_envs/py385dev/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /gpfs/ycga/project/dijk/ngr4/conda_envs/py385dev/lib/python3.8/site-packages/seaborn/matrix.py in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, dendrogram_ratio, colors_ratio, cbar_pos, tree_kws, **kwargs)
#    1400                           colors_ratio=colors_ratio, cbar_pos=cbar_pos)
#    1401
# -> 1402     return plotter.plot(metric=metric, method=method,
#    1403                         colorbar_kws=cbar_kws,
#    1404                         row_cluster=row_cluster, col_cluster=col_cluster,
#
# /gpfs/ycga/project/dijk/ngr4/conda_envs/py385dev/lib/python3.8/site-packages/seaborn/matrix.py in plot(self, metric, method, colorbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, tree_kws, **kws)
#    1218         colorbar_kws = {} if colorbar_kws is None else colorbar_kws
#    1219
# -> 1220         self.plot_dendrograms(row_cluster, col_cluster, metric, method,
#    1221                               row_linkage=row_linkage, col_linkage=col_linkage,
#    1222                               tree_kws=tree_kws)
#
# /gpfs/ycga/project/dijk/ngr4/conda_envs/py385dev/lib/python3.8/site-packages/seaborn/matrix.py in plot_dendrograms(self, row_cluster, col_cluster, metric, method, row_linkage, col_linkage, tree_kws)
#    1073         # PLot the column dendrogram
#    1074         if col_cluster:
# -> 1075             self.dendrogram_col = dendrogram(
#    1076                 self.data2d, metric=metric, method=method, label=False,
#    1077                 axis=1, ax=self.ax_col_dendrogram, linkage=col_linkage,
#
# /gpfs/ycga/project/dijk/ngr4/conda_envs/py385dev/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /gpfs/ycga/project/dijk/ngr4/conda_envs/py385dev/lib/python3.8/site-packages/seaborn/matrix.py in dendrogram(data, linkage, axis, label, metric, method, rotate, tree_kws, ax)
#     782
#     783     """
# --> 784     plotter = _DendrogramPlotter(data, linkage=linkage, axis=axis,
#     785                                  metric=metric, method=method,
#     786                                  label=label, rotate=rotate)
#
# /gpfs/ycga/project/dijk/ngr4/conda_envs/py385dev/lib/python3.8/site-packages/seaborn/matrix.py in __init__(self, data, linkage, metric, method, axis, label, rotate)
#     592
#     593         if linkage is None:
# --> 594             self.linkage = self.calculated_linkage
#     595         else:
#     596             self.linkage = linkage
#
# /gpfs/ycga/project/dijk/ngr4/conda_envs/py385dev/lib/python3.8/site-packages/seaborn/matrix.py in calculated_linkage(self)
#     659                 warnings.warn(msg)
#     660
# --> 661         return self._calculate_linkage_scipy()
#     662
#     663     def calculate_dendrogram(self):
#
# /gpfs/ycga/project/dijk/ngr4/conda_envs/py385dev/lib/python3.8/site-packages/seaborn/matrix.py in _calculate_linkage_scipy(self)
#     627
#     628     def _calculate_linkage_scipy(self):
# --> 629         linkage = hierarchy.linkage(self.array, method=self.method,
#     630                                     metric=self.metric)
#     631         return linkage
#
# /gpfs/ycga/project/dijk/ngr4/conda_envs/py385dev/lib/python3.8/site-packages/scipy/cluster/hierarchy.py in linkage(y, method, metric, optimal_ordering)
#    1050                          'matrix looks suspiciously like an uncondensed '
#    1051                          'distance matrix')
# -> 1052         y = distance.pdist(y, metric)
#    1053     else:
#    1054         raise ValueError("`y` must be 1 or 2 dimensional.")
#
# /gpfs/ycga/project/dijk/ngr4/conda_envs/py385dev/lib/python3.8/site-packages/scipy/spatial/distance.py in pdist(X, metric, *args, **kwargs)
#    2055             pdist_fn = getattr(_distance_wrap,
#    2056                                "pdist_%s_%s_wrap" % (metric_name, typ))
# -> 2057             pdist_fn(X, dm, **kwargs)
#    2058             return dm
#    2059
#
# KeyboardInterrupt:

# %%
sns.clustermap(Xprime, cmap='YlOrBr')

# %%
# !pip install fastcluster
